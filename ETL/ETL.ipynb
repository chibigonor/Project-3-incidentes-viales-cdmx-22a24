# %%
import pandas as pd

# %%
# First read the original CSV file in order to get the original dataframe
original_df = pd.read_csv('../Original_CSV/inViales_2022_2024.csv')
original_df.head()
# Out:
#                 folio fecha_creacion hora_creacion dia_semana fecha_cierre  \
# 0  C2C/20211229/00212     2021-12-29      23:21:20  Miércoles   2022-01-01
# 1  C2C/20211231/00183     2021-12-31      23:48:03    Viernes   2022-01-01
# 2  C2C/20220101/00012     2022-01-01      01:06:39     Sábado   2022-01-01
# 3  C2C/20220101/00070     2022-01-01      09:51:53     Sábado   2022-01-01
# 4  C2N/20211231/00128     2021-12-31      23:03:05    Viernes   2022-01-01
#
#   hora_cierre tipo_incidente_c4           incidente_c4 alcaldia_inicio  \
# 0    00:24:06         Lesionado            Atropellado             NaN
# 1    06:29:52         Lesionado            Atropellado      CUAUHTEMOC
# 2    06:00:12         Accidente  Choque con lesionados      CUAUHTEMOC
# 3    12:54:10         Accidente           Motociclista      CUAUHTEMOC
# 4    06:16:42         Accidente  Choque sin lesionados       IZTACALCO
#
#   codigo_cierre  clas_con_f_alarma      tipo_entrada alcaldia_cierre  \
# 0             I  URGENCIAS MEDICAS  BOTÓN DE AUXILIO             NaN
# 1             A  URGENCIAS MEDICAS  BOTÓN DE AUXILIO      CUAUHTEMOC
# 2             A  URGENCIAS MEDICAS  BOTÓN DE AUXILIO      CUAUHTEMOC
# 3             A  URGENCIAS MEDICAS             RADIO      CUAUHTEMOC
# 4             A         EMERGENCIA  BOTÓN DE AUXILIO       IZTACALCO
#
#   alcaldia_catalogo    colonia_catalogo   longitud    latitud
# 0        Cuauhtémoc          Roma Norte -99.163670  19.421610
# 1        Cuauhtémoc              Obrera -99.144270  19.409910
# 2        Cuauhtémoc            Doctores -99.148320  19.415250
# 3    Miguel Hidalgo            Tlaxpana -99.165781  19.443649
# 4         Iztacalco  Agricola Pantitlan -99.060450  19.414620

# %%
#In this section we create a new csv for alcaldias
alcaldias = original_df[['alcaldia_catalogo']].drop_duplicates().rename(columns={'alcaldia_catalogo': 'alcaldia'}).reset_index(drop=True).dropna()
alcaldias['id'] = alcaldias.index + 1
alcaldias = alcaldias[['id', 'alcaldia']]


alcaldias.to_csv('../Mod_CSV/alcaldias.csv', index=False)
alcaldias
# Out:
#     id                alcaldia
# 0    1              Cuauhtémoc
# 1    2          Miguel Hidalgo
# 2    3               Iztacalco
# 3    4     Venustiano Carranza
# 4    5       Gustavo A. Madero
# 5    6              Xochimilco
# 6    7                 Tláhuac
# 7    8              Iztapalapa
# 8    9          Álvaro Obregón
# 9   10            Azcapotzalco
# 10  11                 Tlalpan
# 11  12                Coyoacán
# 12  13              Milpa Alta
# 13  14   Cuajimalpa de Morelos
# 14  15           Benito Juárez
# 15  16  La Magdalena Contreras

# %%
# we drop some alcaldias columns that weren't helpful
original_df_1 = original_df.drop(columns=['alcaldia_inicio','alcaldia_cierre', 'tipo_incidente_c4'])
original_df_1 = original_df_1[original_df_1['incidente_c4'] != 'Persona atropellada']
original_df_1
# Out:
#                      folio fecha_creacion hora_creacion dia_semana  \
# 0       C2C/20211229/00212     2021-12-29      23:21:20  Miércoles
# 1       C2C/20211231/00183     2021-12-31      23:48:03    Viernes
# 2       C2C/20220101/00012     2022-01-01      01:06:39     Sábado
# 3       C2C/20220101/00070     2022-01-01      09:51:53     Sábado
# 4       C2N/20211231/00128     2021-12-31      23:03:05    Viernes
# ...                    ...            ...           ...        ...
# 504256   C5/20240229/04009     2024-02-29      19:53:36     Jueves
# 504257   C5/20240229/04038     2024-02-29      20:01:42     Jueves
# 504258   C5/20240229/04286     2024-02-29      20:43:20     Jueves
# 504259   C5/20240229/04300     2024-02-29      20:46:18     Jueves
# 504260   C5/20240229/04349     2024-02-29      20:53:56     Jueves
#
#        fecha_cierre hora_cierre           incidente_c4 codigo_cierre  \
# 0        2022-01-01    00:24:06            Atropellado             I
# 1        2022-01-01    06:29:52            Atropellado             A
# 2        2022-01-01    06:00:12  Choque con lesionados             A
# 3        2022-01-01    12:54:10           Motociclista             A
# 4        2022-01-01    06:16:42  Choque sin lesionados             A
# ...             ...         ...                    ...           ...
# 504256   2024-02-29    23:16:21  Choque con lesionados             A
# 504257   2024-02-29    23:06:17  Choque con lesionados             A
# 504258   2024-02-29    23:46:22  Choque con lesionados             D
# 504259   2024-02-29    23:56:17           Motociclista             F
# 504260   2024-02-29    23:58:48  Choque sin lesionados             A
#
#         clas_con_f_alarma      tipo_entrada alcaldia_catalogo  \
# 0       URGENCIAS MEDICAS  BOTÓN DE AUXILIO        Cuauhtémoc
# 1       URGENCIAS MEDICAS  BOTÓN DE AUXILIO        Cuauhtémoc
# 2       URGENCIAS MEDICAS  BOTÓN DE AUXILIO        Cuauhtémoc
# 3       URGENCIAS MEDICAS             RADIO    Miguel Hidalgo
# 4              EMERGENCIA  BOTÓN DE AUXILIO         Iztacalco
# ...                   ...               ...               ...
# 504256  URGENCIAS MEDICAS   LLAMADA DEL 911        Iztapalapa
# 504257  URGENCIAS MEDICAS             RADIO        Cuauhtémoc
# 504258  URGENCIAS MEDICAS   LLAMADA DEL 911        Iztapalapa
# 504259  URGENCIAS MEDICAS   LLAMADA DEL 911        Iztapalapa
# 504260         EMERGENCIA   LLAMADA DEL 911        Iztapalapa
#
#            colonia_catalogo   longitud    latitud
# 0                Roma Norte -99.163670  19.421610
# 1                    Obrera -99.144270  19.409910
# 2                  Doctores -99.148320  19.415250
# 3                  Tlaxpana -99.165781  19.443649
# 4        Agricola Pantitlan -99.060450  19.414620
# ...                     ...        ...        ...
# 504256            El Vergel -99.087270  19.320600
# 504257               Centro -99.125200  19.428723
# 504258             Apatlaco -99.119881  19.380011
# 504259  Guadalupe Del Moral -99.080981  19.369412
# 504260         Juan Escutia -99.054112  19.397305
#
# [504235 rows x 14 columns]

# %%
#In this section we create a new csv for alcaldias
tipoincidente = original_df_1[['incidente_c4']].drop_duplicates().rename(columns={'incidente_c4': 'tipo_incidente'}).reset_index(drop=True).dropna()
tipoincidente['id'] = tipoincidente.index + 1
tipoincidente = tipoincidente[['id', 'tipo_incidente']]


tipoincidente.to_csv('../Mod_CSV/tipoincidente.csv', index=False)
tipoincidente
# Out:
#     id                    tipo_incidente
# 0    1                       Atropellado
# 1    2             Choque con lesionados
# 2    3                      Motociclista
# 3    4             Choque sin lesionados
# 4    5                         Volcadura
# 5    6              Choque con prensados
# 6    7            Vehiculo desbarrancado
# 7    8  Persona atrapada / desbarrancada
# 8    9                          Ciclista
# 9   10           Vehículo atrapadovarado
# 10  11         Accidente automovilístico
# 11  12             Incidente de tránsito
# 12  13                             Otros
# 13  14                         Monopatín
# 14  15                       Ferroviario

# %%
# We use the count in order to clean the data
tipo_incidente_counts = original_df_1['incidente_c4'].value_counts()
tipo_incidente_counts_df = tipo_incidente_counts.reset_index().rename(columns={'index': 'tipo_incidente', 'incidente_c4': 'cantidad'})
tipo_incidente_counts_df
# Out:
#                             cantidad   count
# 0              Choque sin lesionados  231050
# 1              Choque con lesionados  146747
# 2                        Atropellado   52724
# 3                       Motociclista   50294
# 4                          Volcadura    9040
# 5                           Ciclista    6603
# 6   Persona atrapada / desbarrancada    2718
# 7            Vehículo atrapadovarado    2069
# 8               Choque con prensados     936
# 9          Accidente automovilístico     849
# 10             Incidente de tránsito     382
# 11            Vehiculo desbarrancado     263
# 12                             Otros     263
# 13                         Monopatín     204
# 14                       Ferroviario      93

# %%
colonias = original_df[['colonia_catalogo']].drop_duplicates().rename(columns={'colonia_catalogo': 'colonia'}).reset_index(drop=True).dropna()
colonias['id'] = colonias.index + 1
colonias = colonias[['id', 'colonia']]
colonias.to_csv('../Mod_CSV/colonias.csv', index=False)
colonias
# Out:
#         id                            colonia
# 0        1                         Roma Norte
# 1        2                             Obrera
# 2        3                           Doctores
# 3        4                           Tlaxpana
# 4        5                 Agricola Pantitlan
# ...    ...                                ...
# 1400  1401               Rinconada De Tarango
# 1401  1402                        El Politoco
# 1402  1403  Barrio Guadalupe Sta Catarina Yec
# 1403  1404                           La Presa
# 1404  1405                           La Araña
#
# [1404 rows x 2 columns]

# %%
codigo_cierre = original_df[['codigo_cierre']].drop_duplicates().rename(columns={'codigo_cierre': 'codigo'}).reset_index(drop=True).dropna() 
codigo_cierre['id'] = codigo_cierre.index + 1
descripcion_mapping = { 'A': 'Afirmativo', 'N': 'Negativo', 'I': 'Informativo', 'D': 'Duplicados', 'F': 'Falso' }
codigo_cierre['descripcion'] = codigo_cierre['codigo'].map(descripcion_mapping)
codigo_cierre = codigo_cierre[['id', 'codigo', 'descripcion']]
codigo_cierre.to_csv('../Mod_CSV/codigo_cierre.csv', index=False)
codigo_cierre
# Out:
#    id codigo  descripcion
# 0   1      I  Informativo
# 1   2      A   Afirmativo
# 2   3      D   Duplicados
# 3   4      F        Falso

# %%
tipo_entrada = original_df[['tipo_entrada']].drop_duplicates().rename(columns={'tipo_entrada': 'tipo_entrada'}).reset_index(drop=True).dropna() 
tipo_entrada['id'] = tipo_entrada.index + 1
tipo_entrada = tipo_entrada[['id', 'tipo_entrada']]
tipo_entrada.to_csv('../Mod_CSV/tipo_entrada.csv', index=False)
tipo_entrada
# Out:
#    id      tipo_entrada
# 0   1  BOTÓN DE AUXILIO
# 1   2             RADIO
# 2   3   LLAMADA DEL 911
# 3   4            CÁMARA
# 4   5             REDES
# 5   6       APLICATIVOS
# 6   7    LLAMADA APP911
# 8   9  LECTOR DE PLACAS
# 9  10  SOS MUJERES *765

# %%
clasificacion_alarma = original_df[['clas_con_f_alarma']].drop_duplicates().rename(columns={'clas_con_f_alarma': 'clasificacion'}).reset_index(drop=True).dropna()
clasificacion_alarma['id'] = clasificacion_alarma.index + 1
clasificacion_alarma = clasificacion_alarma[['id', 'clasificacion']]
clasificacion_alarma.to_csv('../Mod_CSV/clasificacion_alarma.csv', index=False)
clasificacion_alarma
# Out:
#    id        clasificacion
# 0   1    URGENCIAS MEDICAS
# 1   2           EMERGENCIA
# 2   3               DELITO
# 3   4         FALSA ALARMA
# 4   5  INCIDENTES EXTERNOS

# %%
incidentes = original_df_1.copy()
incidentes = incidentes.merge(alcaldias[['id', 'alcaldia']], how='left', left_on='alcaldia_catalogo', right_on='alcaldia').rename(columns={'id': 'alcaldia_catalogo_id'})
incidentes = incidentes.merge(tipoincidente[['id', 'tipo_incidente']], how='left', left_on='incidente_c4', right_on='tipo_incidente').rename(columns={'id': 'tipo_incidente_id'})
incidentes = incidentes.merge(codigo_cierre[['id', 'codigo']], how='left', on='codigo_cierre').rename(columns={'id': 'codigo_cierre_id'})


incidentes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21800\397008458.py in ?()
#       1 incidentes = original_df_1.copy()
#       2 incidentes = incidentes.merge(alcaldias[['id', 'alcaldia']], how='left', left_on='alcaldia_catalogo', right_on='alcaldia').rename(columns={'id': 'alcaldia_catalogo_id'})
#       3 incidentes = incidentes.merge(tipoincidente[['id', 'tipo_incidente']], how='left', left_on='incidente_c4', right_on='tipo_incidente').rename(columns={'id': 'tipo_incidente_id'})
# ----> 4 incidentes = incidentes.merge(codigo_cierre[['id', 'codigo']], how='left', on='codigo_cierre').rename(columns={'id': 'codigo_cierre_id'})
#       5
#       6
#       7 incidentes
#
# c:\Users\Javier Alarcon\anaconda3\envs\dev\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10483         validate: MergeValidate | None = None,
#   10484     ) -> DataFrame:
#   10485         from pandas.core.reshape.merge import merge
#   10486
# > 10487         return merge(
#   10488             self,
#   10489             right,
#   10490             how=how,
#
# c:\Users\Javier Alarcon\anaconda3\envs\dev\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# c:\Users\Javier Alarcon\anaconda3\envs\dev\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     787             self.right_join_keys,
#     788             self.join_names,
#     789             left_drop,
#     790             right_drop,
# --> 791         ) = self._get_merge_keys()
#     792
#     793         if left_drop:
#     794             self.left = self.left._drop_labels_or_levels(left_drop)
#
# c:\Users\Javier Alarcon\anaconda3\envs\dev\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1265                         # Then we're either Hashable or a wrong-length arraylike,
#    1266                         #  the latter of which will raise
#    1267                         rk = cast(Hashable, rk)
#    1268                         if rk is not None:
# -> 1269                             right_keys.append(right._get_label_or_level_values(rk))
#    1270                         else:
#    1271                             # work-around for merge_asof(right_index=True)
#    1272                             right_keys.append(right.index._values)
#
# c:\Users\Javier Alarcon\anaconda3\envs\dev\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'codigo_cierre'
